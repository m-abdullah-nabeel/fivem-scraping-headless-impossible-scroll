# %%
# !pip install selenium

# %%
# ! pip install webdriver_manager

# %%
import time
from threading import Thread
import logging
import os
from datetime import datetime
import re

import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait, Select
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import TimeoutException, StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains

print("Working")
# Out:
# Working

# %%
# ------------- Global Vars -------------
# CWD = os.path.dirname(os.path.realpath(__file__))
CWD = os.path.dirname(os.path.realpath("./"))
tdt = datetime.now()
td = datetime.now().strftime('%m-%d-%Y')
FIVEM_URL = 'https://servers.fivem.net/servers'
BASE_URL = 'https://servers.fivem.net/servers/detail/{}'
FIVEM_OUTPUT = os.path.join(CWD, 'FiveMScraper.csv')

print("Working")
# Out:
# Working

# %%
# ------------- Logging Configuration -------------
log_file_path = os.path.join(CWD, f"fivem_scraper.log")
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
file_handler = logging.FileHandler(filename=log_file_path, mode="w", encoding="UTF-8")
file_handler.setFormatter(
    logging.Formatter("%(asctime)s-%(levelname)s: Func-%(funcName)s : Line-%(lineno)d : %(message)s"))
logger.addHandler(file_handler)
logger.addHandler(logging.StreamHandler())
logger.debug(f"\n{'-' * 21} FiveM Scraper == Started at -> {tdt.strftime('%d-%m-%Y %I:%M:%S %p')} {'-' * 21}")
logger.info(f"Current Working Directory: {CWD}")
logger.info(f"Current Date & Time: {tdt.strftime('%d-%m-%Y %I:%M:%S %p')}")
logger.info(f"Log File Path: {log_file_path}")
logger.info(f"OUTPUT File Path: {FIVEM_OUTPUT}")
# ------------- Starter Code -------------
logging.getLogger('WDM').setLevel(logging.CRITICAL)
os.environ['WDM_LOG'] = '0'
# DRIVER_PATH = ChromeDriverManager(version="114.0.5735.90").install()
# logger.info(f"Chrome Driver File Path: {log_file_path}")
# Out:
# --------------------- FiveM Scraper == Started at -> 22-10-2023 07:47:10 PM ---------------------
# Current Working Directory: C:\Users\muham\Desktop
# Current Date & Time: 22-10-2023 07:47:10 PM
# Log File Path: C:\Users\muham\Desktop\fivem_scraper.log
# OUTPUT File Path: C:\Users\muham\Desktop\FiveMScraper.csv

# %%
def push_data(data):
    if not os.path.exists(FIVEM_OUTPUT):
        df = pd.DataFrame(
            columns=["Server Name", "FiveM Server Link", "Developer", "Game type", "Map", "OneSync", "Language",
                     "Tags", "DLC level", "sv_purelevel", "Owner", "DiscordLink", "Extracted_Link", "Resources Section"])
        df.loc[df.shape[0]] = data
        df.to_csv(FIVEM_OUTPUT, index=False)  # Save as CSV

    else:
        df = pd.read_csv(FIVEM_OUTPUT)  # Read existing CSV
        df.loc[df.shape[0]] = data
        df.to_csv(FIVEM_OUTPUT, index=False)  # Save as CSV

# %%
def get_last_processed_index():
    if os.path.exists(FIVEM_OUTPUT):
        df = pd.read_csv(FIVEM_OUTPUT)
        return df.shape[0]
    return 0

# %%
class FiveMScraper:
    def __init__(self):
        """
        To initialize driver and wait objects
        """
        self.main_window = None
        self.index_count = 0
        self.data = ["", "", "", "", "", "", "", "", "", "", "", "", "", ""]
        user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'
        
      
        # Create driver and Options
        chrome_options = Options()
        chrome_options.add_argument('--ignore-certificate-errors')
        chrome_options.add_argument(f'user-agent={user_agent}')
        chrome_options.add_argument("--disable-session-crashed-bubble")
        chrome_options.add_argument("--disable-notifications")
        chrome_options.add_argument("--suppress-message-center-popups")
#         chrome_options.add_argument('--disable-logging')
#         chrome_options.add_argument("--disable-translate")
        chrome_options.add_argument("--no-first-run")
        chrome_options.add_argument("--disable-extensions")
        chrome_options.add_argument("--disable-blink-features=AutomationControlled")
        chrome_options.add_argument("disable-infobars")
        #headless
        chrome_options.add_argument('--headless')
        chrome_options.add_argument('--disable-gpu')
        chrome_options.add_argument('--no-sandbox')
        chrome_options.add_argument("--start-maximized")
        chrome_options.add_argument("--window-size=1920x1080")
        #headless
        chrome_options.add_experimental_option("excludeSwitches", ["enable-automation", "enable-logging"])
        chrome_options.add_experimental_option('useAutomationExtension', False)
        chrome_options.add_experimental_option("excludeSwitches", ["enable-logging", "test-type"])
        
        self.__driver = webdriver.Chrome(service=Service(r"chromedriver.exe"), options=chrome_options)
        self.__wait = WebDriverWait(self.__driver, 60)        
#         self.__action = ActionChains(self.__driver)

    def fetch_data(self, server_id):
        url = BASE_URL.format(server_id)
        logger.info(f"{url}")
        self.__driver.switch_to.window("review_details")
        self.__driver.get(url)

        try:
            self.data[1] = url
            snamez = self.__driver.find_element(By.XPATH, '(//span)[24]')
            # //div[@class="info"]//div[@class="title"][1]
            server_namez = snamez.text
            print(server_namez)

            pattern = r"discord\.gg/[a-zA-Z0-9]+(?:\.[a-zA-Z]+)?"
            links = re.findall(pattern, server_namez)
            if links:
                print("Found link(s):")
                print(links)
                self.data[12] = links
            else:
                print("no links")
                self.data[12] = " "
        except:
            pass

        resource_list = []
        resources = self.__wait.until(
            EC.presence_of_all_elements_located((By.XPATH, '(//ul)[3]/li')))
        for resource in resources:
            resource_list.append(resource.text)
            #logger.info(f"Resource: {resource.text}")
        self.data[13] = resource_list
        logger.info(f"Resources: {', '.join(resource_list)}")

        # player_list = []
        # players = self.__wait.until(
        #     EC.presence_of_all_elements_located((By.XPATH, '(//ul)[4]/li')))
        # for player in players:
        #     player_list.append(player.text)
        #     logger.info(f"Player: {player.text}")
        
#         self.data[1] = url

        # time.sleep(5)
        tags = self.__wait.until(
            EC.presence_of_all_elements_located((By.XPATH, '(//ul)[2]/li')))
        # for index in range(len(tags)):
        for tag in tags:
            # key = self.__wait.until(
            #     EC.presence_of_element_located((By.XPATH, f'(//ul)[2]/li[{index + 1}]/span[1]')))
            # value = self.__wait.until(
            #     EC.presence_of_element_located((By.XPATH, f'(//ul)[2]/li[{index + 1}]/span[2]')))
            key = WebDriverWait(tag, 60).until(
                EC.presence_of_element_located((By.XPATH, './span[1]')))

            value = WebDriverWait(tag, 60).until(
                EC.presence_of_element_located((By.XPATH, './span[2]')))

            # ["Server Name", "FiveM Server Link", "Resources Section", "Game type", "Map", "OneSync", "Language",
            #  "Tags", "DLC level", "sv_purelevel", "Owner", "DiscordLink", "Developer"]
            key = key.text
            value = value.text
            logger.info(f"{key}: {value}")
            if key == 'Game type':
                self.data[3] = value
            elif key == 'OneSync':
                self.data[4] = value
            elif key == 'Map':
                self.data[5] = value
            elif key == 'Language':
                self.data[6] = value
            elif key == 'Tags':
                self.data[7] = value
            elif key == 'DLC level':
                self.data[8] = value
            elif key == 'sv_purelevel':
                self.data[9] = value
            elif key == 'Owner':
                self.data[10] = value
            elif key == 'Developer':
                self.data[2] = value
            elif key == 'DiscordLink':
                self.data[11] = value
            # logger.info(f"Tag: {tag.text}")

        print("=========================>")
        print(self.data[6])
#         if "english" in self.data[6].lower():
#             print("The language is English, now pushing data")
#             push_data(self.data)

        push_data(self.data)
        self.data = ["", "", "", "", "", "", "",
                     "", "", "", "", "", "",""]
        self.__driver.switch_to.window(self.__driver.window_handles[0])

        
        
    def start(self):
        print("Waiting to open and load")
        self.__driver.get(FIVEM_URL)
        
#         self.main_window = self.__driver.current_window_handle
#         self.__driver.execute_script("window.open('about:blank','review_details');")

        server_list = self.__wait.until(
            EC.presence_of_all_elements_located((By.XPATH, '//servers-list-item/a/figure/img')))
        titles = self.__wait.until(
            EC.presence_of_all_elements_located((By.XPATH, '//servers-list-item/a/div[4]/strong/span')))
        
        print(len(server_list))

        print("Waiting for empty box")
        fsl = WebDriverWait(self.__driver, 60).until(
            EC.presence_of_element_located((By.XPATH, "//servers-list"))
        )
        
        print("fsl")
        print(fsl)
        
        print("Waiting for servers container scroll div")
        sdiv = WebDriverWait(fsl, 60).until(
            EC.presence_of_element_located((By.CLASS_NAME, "cdk-virtual-scroll-content-wrapper"))
        )
        
        print("sdiv")
        print(sdiv)

        print("Waiting for very first servers list / items")

        time.sleep(60)
        self.__driver.get_screenshot_as_file("screenshot1.png")
        print("Screenshot 1")

        time.sleep(60)
        self.__driver.get_screenshot_as_file("screenshot2.png")
        print("Screenshot 2")
        
        time.sleep(60)
        self.__driver.get_screenshot_as_file("screenshot3.png")
        print("Screenshot 3")

        sname = WebDriverWait(sdiv, 60).until(
            EC.presence_of_element_located((By.XPATH, ".//*"))
        )
        
        print("sname")
        print(sname)
        print(type(sname))
        print(sname.text)

        print("Waiting for list of servers / items")
                
        snl = WebDriverWait(sdiv, 5).until(
            EC.presence_of_all_elements_located((By.XPATH, ".//*"))
        )
        
        print("snl")
        print(len(snl))

        for i in range(len(snl)):
            print(i)
            print(snl[i])
            print(snl[i].text)
#             print(snl[i].get_attribute('href'))
#             print("__________________")
#             print(snl[i].find_element(By.XPATH, ".//a/figure/img"))
            
#         snl[3].click()
#         for i in range(1, 1000): 
#             print(i)
#             print("Wait...")
# #             lname = WebDriverWait(sdiv, 15).until(
# #                 EC.presence_of_element_located((By.XPATH, f".//*[{i}]"))
# #             )
#             lname = snl[i]

#             self.__driver.execute_script("arguments[0].scrollIntoView();", lname)
#             print(lname.text)
#             time.sleep(5)
#             link = WebDriverWait(lname, 15).until(
#                 EC.presence_of_element_located((By.XPATH, f".//a/figure/img")))

#             print(link.get_attribute('src'))
            
#             mte = ActionChains(self.__driver).scroll_to_element(lname).perform()

#         for index in range(len(server_list)):
#             # try:
#             self.data = ["", "", "", "", "", "", "", "", "", "", "", "", "", ""]
#             image_url = server_list[index].get_attribute('src')
#             logger.info(f"{image_url}")
#             server_id_ = image_url.split('/')[-2]
#             server_name = titles[index].text
#             server_ids.append(server_id_)
#             logger.info(f"Server Name: {server_name}")
#             self.data[0] = server_name
#             logger.info(f"Server ID: {server_id_}")
# #             self.fetch_data(server_id_)
#             # except:
#             #     print("exception")
#             #     pass

print("Updated")
# Out:
# Updated

# %%
if __name__ == "__main__":
    bot = FiveMScraper()
    bot.start()
# Out:
# Waiting to open and load
# 56
# Waiting for empty box
# fsl
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_6")>
# Waiting for servers container scroll div
# sdiv
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_195")>
# Waiting for very first servers list / items
# Screenshot 1
# Screenshot 2
# Screenshot 3
# sname
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_244")>
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# Pt
# Envy Roleplay Serious Roleplay ServerNodus Nopix Echo Lucid Viper Familia Rp Windy City Svrp PMA District 10 ALTF4 Highlife Ignite LA Noire
# roleplay default rp police
# 235/250
# Waiting for list of servers / items
# snl
# 1000
# 0
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_244")>
# Pt
# Envy Roleplay Serious Roleplay ServerNodus Nopix Echo Lucid Viper Familia Rp Windy City Svrp PMA District 10 ALTF4 Highlife Ignite LA Noire
# roleplay default rp police
# 235/250
# 1
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_245")>
# Pt
# Envy Roleplay Serious Roleplay ServerNodus Nopix Echo Lucid Viper Familia Rp Windy City Svrp PMA District 10 ALTF4 Highlife Ignite LA Noire
# roleplay default rp police
# 235/250
# 2
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_246")>
#
# 3
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_247")>
#
# 4
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_80")>
#
# 5
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_248")>
# Pt
# 6
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_249")>
# Pt
# 7
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_250")>
# Pt
# 8
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_251")>
#
# 9
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_252")>
#
# 10
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_253")>
# Envy Roleplay Serious Roleplay ServerNodus Nopix Echo Lucid Viper Familia Rp Windy City Svrp PMA District 10 ALTF4 Highlife Ignite LA Noire
# 11
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_254")>
# Envy Roleplay Serious Roleplay Server
# 12
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_137")>
# Envy Roleplay Serious Roleplay Server
# 13
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_255")>
# Nodus Nopix Echo Lucid Viper Familia Rp Windy City Svrp PMA District 10 ALTF4 Highlife Ignite LA Noire
# 14
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_256")>
# roleplay default rp police
# 15
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_257")>
# roleplay
# 16
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_258")>
# default
# 17
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_259")>
# rp
# 18
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_260")>
# police
# 19
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_261")>
#
# 20
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_262")>
#
# 21
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_263")>
#
# 22
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_264")>
#
# 23
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_265")>
# 235/250
# 24
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_266")>
# /250
# 25
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_267")>
# Pt
# HYPIX Serious ROLEPLAYHYPIX, Serious RP, One of The fastest growing RP communities
# roleplay rp police drugs
# 69/140
# 26
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_268")>
# Pt
# HYPIX Serious ROLEPLAYHYPIX, Serious RP, One of The fastest growing RP communities
# roleplay rp police drugs
# 69/140
# 27
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_269")>
#
# 28
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_270")>
#
# 29
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_81")>
#
# 30
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_271")>
# Pt
# 31
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_272")>
# Pt
# 32
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_273")>
# Pt
# 33
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_274")>
#
# 34
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_275")>
#
# 35
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_276")>
# HYPIX Serious ROLEPLAYHYPIX, Serious RP, One of The fastest growing RP communities
# 36
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_277")>
# HYPIX Serious ROLEPLAY
# 37
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_138")>
# HYPIX Serious ROLEPLAY
# 38
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_278")>
# HYPIX, Serious RP, One of The fastest growing RP communities
# 39
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_279")>
# roleplay rp police drugs
# 40
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_280")>
# roleplay
# 41
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_281")>
# rp
# 42
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_282")>
# police
# 43
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_283")>
# drugs
# 44
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_284")>
#
# 45
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_285")>
#
# 46
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_286")>
#
# 47
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_287")>
#
# 48
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_288")>
# 69/140
# 49
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_289")>
# /140
# 50
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_290")>
# Pt
# LaVoute Roleplay 2.0! Grand Opening!!!Serious Roleplay, Custom Gangs & Jobs, Custom Cars & Clothing! Discord.gg/LaVoute
# roleplay drugs serious gangs
# 25/200
# 51
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_291")>
# Pt
# LaVoute Roleplay 2.0! Grand Opening!!!Serious Roleplay, Custom Gangs & Jobs, Custom Cars & Clothing! Discord.gg/LaVoute
# roleplay drugs serious gangs
# 25/200
# 52
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_292")>
#
# 53
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_293")>
#
# 54
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_82")>
#
# 55
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_294")>
# Pt
# 56
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_295")>
# Pt
# 57
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_296")>
# Pt
# 58
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_297")>
#
# 59
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_298")>
#
# 60
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_299")>
# LaVoute Roleplay 2.0! Grand Opening!!!Serious Roleplay, Custom Gangs & Jobs, Custom Cars & Clothing! Discord.gg/LaVoute
# 61
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_300")>
# LaVoute Roleplay 2.0! Grand Opening!!!
# 62
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_139")>
# LaVoute Roleplay 2.0! Grand Opening!!!
# 63
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_301")>
# Serious Roleplay, Custom Gangs & Jobs, Custom Cars & Clothing! Discord.gg/LaVoute
# 64
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_302")>
# roleplay drugs serious gangs
# 65
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_303")>
# roleplay
# 66
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_304")>
# drugs
# 67
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_305")>
# serious
# 68
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_306")>
# gangs
# 69
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_307")>
#
# 70
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_308")>
#
# 71
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_309")>
#
# 72
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_310")>
#
# 73
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_311")>
# 25/200
# 74
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_312")>
# /200
# 75
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_313")>
# Pt
# NEW ✘ FULL SEND ✘ RPSerious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring full send rp
# roleplay police drugs ems
# 69/200
# 76
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_314")>
# Pt
# NEW ✘ FULL SEND ✘ RPSerious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring full send rp
# roleplay police drugs ems
# 69/200
# 77
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_315")>
#
# 78
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_316")>
#
# 79
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_83")>
#
# 80
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_317")>
# Pt
# 81
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_318")>
# Pt
# 82
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_319")>
# Pt
# 83
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_320")>
#
# 84
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_321")>
#
# 85
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_322")>
# NEW ✘ FULL SEND ✘ RPSerious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring full send rp
# 86
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_323")>
# NEW ✘ FULL SEND ✘ RP
# 87
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_140")>
# NEW ✘ FULL SEND ✘ RP
# 88
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_324")>
# Serious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring full send rp
# 89
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_325")>
# roleplay police drugs ems
# 90
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_326")>
# roleplay
# 91
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_327")>
# police
# 92
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_328")>
# drugs
# 93
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_329")>
# ems
# 94
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_330")>
#
# 95
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_331")>
#
# 96
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_332")>
#
# 97
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_333")>
#
# 98
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_334")>
# 69/200
# 99
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_335")>
# /200
# 100
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_336")>
# Pt
# Punisher RP ⤳Discord.gg/pc [ سيرفر عرب بونيشر ]
# vrp
# 337/500
# 101
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_337")>
# Pt
# Punisher RP ⤳Discord.gg/pc [ سيرفر عرب بونيشر ]
# vrp
# 337/500
# 102
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_338")>
#
# 103
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_339")>
#
# 104
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_84")>
#
# 105
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_340")>
# Pt
# 106
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_341")>
# Pt
# 107
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_342")>
# Pt
# 108
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_343")>
#
# 109
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_344")>
#
# 110
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_345")>
# Punisher RP ⤳Discord.gg/pc [ سيرفر عرب بونيشر ]
# 111
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_346")>
# Punisher RP ⤳
# 112
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_141")>
# Punisher RP ⤳
# 113
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_347")>
# Discord.gg/pc [ سيرفر عرب بونيشر ]
# 114
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_348")>
# vrp
# 115
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_349")>
# vrp
# 116
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_350")>
#
# 117
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_351")>
#
# 118
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_352")>
#
# 119
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_353")>
#
# 120
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_354")>
# 337/500
# 121
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_355")>
# /500
# 122
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_356")>
# Pt
# Laguna RPSerious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring Prodigy Laguna RP
# roleplay police drugs ems
# 0/100
# 123
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_357")>
# Pt
# Laguna RPSerious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring Prodigy Laguna RP
# roleplay police drugs ems
# 0/100
# 124
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_358")>
#
# 125
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_359")>
#
# 126
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_85")>
#
# 127
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_360")>
# Pt
# 128
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_361")>
# Pt
# 129
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_362")>
# Pt
# 130
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_363")>
#
# 131
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_364")>
#
# 132
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_365")>
# Laguna RPSerious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring Prodigy Laguna RP
# 133
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_366")>
# Laguna RP
# 134
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_142")>
# Laguna RP
# 135
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_367")>
# Serious Roleplay Realistic Economy PD EMS Allowlisted Jobs Hiring Prodigy Laguna RP
# 136
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_368")>
# roleplay police drugs ems
# 137
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_369")>
# roleplay
# 138
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_370")>
# police
# 139
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_371")>
# drugs
# 140
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_372")>
# ems
# 141
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_373")>
#
# 142
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_374")>
#
# 143
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_375")>
#
# 144
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_376")>
#
# 145
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_377")>
# 0/100
# 146
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_378")>
# /100
# 147
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_379")>
# Pt
# CashLife RP🎃100KORDIE TRAP PHANTOM SOB MIGHETTO drilla Mercury narco 173 187RP theheights thehills JUMP DEMONS BACKNBLOOD STRAPUP 891 SEM
# roleplay police drugs ems
# 56/150
# 148
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_380")>
# Pt
# CashLife RP🎃100KORDIE TRAP PHANTOM SOB MIGHETTO drilla Mercury narco 173 187RP theheights thehills JUMP DEMONS BACKNBLOOD STRAPUP 891 SEM
# roleplay police drugs ems
# 56/150
# 149
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_381")>
#
# 150
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_382")>
#
# 151
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_86")>
# 152
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_383")>
# Pt
# 153
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_384")>
# Pt
# 154
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_385")>
# Pt
# 155
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_386")>
#
# 156
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_387")>
#
# 157
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_388")>
# CashLife RP🎃100KORDIE TRAP PHANTOM SOB MIGHETTO drilla Mercury narco 173 187RP theheights thehills JUMP DEMONS BACKNBLOOD STRAPUP 891 SEM
# 158
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_389")>
# CashLife RP🎃
# 159
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_143")>
# CashLife RP🎃
# 160
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_390")>
# 100KORDIE TRAP PHANTOM SOB MIGHETTO drilla Mercury narco 173 187RP theheights thehills JUMP DEMONS BACKNBLOOD STRAPUP 891 SEM
# 161
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_391")>
# roleplay police drugs ems
# 162
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_392")>
# roleplay
# 163
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_393")>
# police
# 164
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_394")>
# drugs
# 165
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_395")>
# ems
# 166
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_396")>
#
# 167
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_397")>
#
# 168
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_398")>
#
# 169
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_399")>
#
# 170
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_400")>
# 56/150
# 171
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_401")>
# /150
# 172
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_402")>
# Pt
# MEXICO CITYNEUERÖFFNUNG ✘ Filmreifes RP ✘ IC Einreise ✘ POWERED BY NARCO CITY ✘ discord.gg/mexicocity
# esx
# 149/1069
# 173
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_403")>
# Pt
# MEXICO CITYNEUERÖFFNUNG ✘ Filmreifes RP ✘ IC Einreise ✘ POWERED BY NARCO CITY ✘ discord.gg/mexicocity
# esx
# 149/1069
# 174
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_404")>
#
# 175
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_405")>
#
# 176
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_87")>
#
# 177
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_406")>
# Pt
# 178
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_407")>
# Pt
# 179
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_408")>
# Pt
# 180
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_409")>
#
# 181
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_410")>
#
# 182
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_411")>
# MEXICO CITYNEUERÖFFNUNG ✘ Filmreifes RP ✘ IC Einreise ✘ POWERED BY NARCO CITY ✘ discord.gg/mexicocity
# 183
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_412")>
# MEXICO CITY
# 184
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_144")>
# MEXICO CITY
# 185
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_413")>
# NEUERÖFFNUNG ✘ Filmreifes RP ✘ IC Einreise ✘ POWERED BY NARCO CITY ✘ discord.gg/mexicocity
# 186
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_414")>
# esx
# 187
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_415")>
# esx
# 188
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_416")>
#
# 189
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_417")>
#
# 190
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_418")>
#
# 191
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_419")>
#
# 192
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_420")>
# 149/1069
# 193
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_421")>
# /1069
# 194
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_422")>
# Pt
# GANGSTA PARADISESEASON #2 RELEASED! Fraktionen gesucht!
# esx roleplay gangs de
# 2/1337
# 195
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_423")>
# Pt
# GANGSTA PARADISESEASON #2 RELEASED! Fraktionen gesucht!
# esx roleplay gangs de
# 2/1337
# 196
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_424")>
#
# 197
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_425")>
#
# 198
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_88")>
#
# 199
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_426")>
# Pt
# 200
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_427")>
# Pt
# 201
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_428")>
# Pt
# 202
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_429")>
#
# 203
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_430")>
#
# 204
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_431")>
# GANGSTA PARADISESEASON #2 RELEASED! Fraktionen gesucht!
# 205
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_432")>
# GANGSTA PARADISE
# 206
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_145")>
# GANGSTA PARADISE
# 207
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_433")>
# SEASON #2 RELEASED! Fraktionen gesucht!
# 208
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_434")>
# esx roleplay gangs de
# 209
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_435")>
# esx
# 210
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_436")>
# roleplay
# 211
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_437")>
# gangs
# 212
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_438")>
# de
# 213
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_439")>
#
# 214
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_440")>
#
# 215
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_441")>
#
# 216
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_442")>
#
# 217
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_443")>
# 2/1337
# 218
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_444")>
# /1337
# 219
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_445")>
# Pt
# MiGhettoNYC NEW UPDATE🗽MiGhetto DISTRICT GRIZZLEY NYC THE TOWNS HEIGHTS HILLS ZOOYORK NOPIX JUNGLE 187 TRAPPIN 100K SEMI SOB THUGLIFE TRUE STORY CUR
# esx legacy
# 77/250
# 220
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_446")>
# Pt
# MiGhettoNYC NEW UPDATE🗽MiGhetto DISTRICT GRIZZLEY NYC THE TOWNS HEIGHTS HILLS ZOOYORK NOPIX JUNGLE 187 TRAPPIN 100K SEMI SOB THUGLIFE TRUE STORY CUR
# esx legacy
# 77/250
# 221
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_447")>
#
# 222
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_448")>
#
# 223
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_89")>
#
# 224
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_449")>
# Pt
# 225
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_450")>
# Pt
# 226
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_451")>
# Pt
# 227
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_452")>
#
# 228
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_453")>
#
# 229
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_454")>
# MiGhettoNYC NEW UPDATE🗽MiGhetto DISTRICT GRIZZLEY NYC THE TOWNS HEIGHTS HILLS ZOOYORK NOPIX JUNGLE 187 TRAPPIN 100K SEMI SOB THUGLIFE TRUE STORY CUR
# 230
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_455")>
# MiGhettoNYC NEW UPDATE🗽
# 231
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_146")>
# MiGhettoNYC NEW UPDATE🗽
# 232
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_60")>
# MiGhetto DISTRICT GRIZZLEY NYC THE TOWNS HEIGHTS HILLS ZOOYORK NOPIX JUNGLE 187 TRAPPIN 100K SEMI SOB THUGLIFE TRUE STORY CUR
# 233
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_456")>
# esx legacy
# 234
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_457")>
# esx
# 235
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_458")>
# legacy
# 236
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_459")>
#
# 237
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_460")>
#
# 238
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_461")>
#
# 239
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_462")>
#
# 240
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_463")>
# 77/250
# 241
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_464")>
# /250
# 242
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_465")>
# Pt
# MiGhettoRP NEW UPDATE🔥Cursed StrapUp 187 SSB rzrp Trappin ThugLife TMF SOB 100k semi Hill mercury murda fatal demon grizzley d10 heights rags2riche
# esx roleplay police drugs
# 170/350
# 243
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_466")>
# Pt
# MiGhettoRP NEW UPDATE🔥Cursed StrapUp 187 SSB rzrp Trappin ThugLife TMF SOB 100k semi Hill mercury murda fatal demon grizzley d10 heights rags2riche
# esx roleplay police drugs
# 170/350
# 244
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_467")>
#
# 245
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_468")>
#
# 246
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_90")>
#
# 247
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_469")>
# Pt
# 248
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_470")>
# Pt
# 249
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_471")>
# Pt
# 250
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_472")>
#
# 251
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_473")>
#
# 252
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_474")>
# MiGhettoRP NEW UPDATE🔥Cursed StrapUp 187 SSB rzrp Trappin ThugLife TMF SOB 100k semi Hill mercury murda fatal demon grizzley d10 heights rags2riche
# 253
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_475")>
# MiGhettoRP NEW UPDATE🔥
# 254
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_147")>
# MiGhettoRP NEW UPDATE🔥
# 255
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_476")>
# Cursed StrapUp 187 SSB rzrp Trappin ThugLife TMF SOB 100k semi Hill mercury murda fatal demon grizzley d10 heights rags2riche
# 256
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_477")>
# esx roleplay police drugs
# 257
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_478")>
# esx
# 258
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_479")>
# roleplay
# 259
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_480")>
# police
# 260
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_481")>
# drugs
# 261
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_482")>
#
# 262
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_483")>
#
# 263
# ...
#
# 911
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1077")>
# Pt
# 912
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1078")>
# Pt
# 913
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1079")>
# Pt
# 914
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1080")>
#
# 915
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1081")>
#
# 916
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1082")>
# CIDADE SANTA ROLEPLAY #WIPE HOJEENTRE E GANHE UM CARRO, FACS E ORGS LIVRES, O MAIS OTIMIZADO DO BRASIL #SANTAGROUP
# 917
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1083")>
# CIDADE SANTA ROLEPLAY #WIPE HOJE
# 918
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_175")>
# CIDADE SANTA ROLEPLAY #WIPE HOJE
# 919
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1084")>
# ENTRE E GANHE UM CARRO, FACS E ORGS LIVRES, O MAIS OTIMIZADO DO BRASIL #SANTAGROUP
# 920
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1085")>
# vrp brasil
# 921
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1086")>
# vrp
# 922
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1087")>
# brasil
# 923
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1088")>
#
# 924
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1089")>
#
# 925
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1090")>
#
# 926
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1091")>
#
# 927
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1092")>
# 479/2048
# 928
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1093")>
# /2048
# 929
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1094")>
# Pt
# CIDADE NOBRE ROLEPLAY #WIPE AGORAENTRE E GANHE UM CARRO, FACS E ORGS LIVRES, O MAIS OTIMIZADO DO BRASIL #SANTAGROUP
# vrp brasil
# 326/2048
# 930
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1095")>
# Pt
# CIDADE NOBRE ROLEPLAY #WIPE AGORAENTRE E GANHE UM CARRO, FACS E ORGS LIVRES, O MAIS OTIMIZADO DO BRASIL #SANTAGROUP
# vrp brasil
# 326/2048
# 931
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1096")>
#
# 932
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1097")>
#
# 933
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_119")>
#
# 934
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1098")>
# Pt
# 935
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1099")>
# Pt
# 936
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1100")>
# Pt
# 937
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1101")>
#
# 938
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1102")>
#
# 939
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1103")>
# CIDADE NOBRE ROLEPLAY #WIPE AGORAENTRE E GANHE UM CARRO, FACS E ORGS LIVRES, O MAIS OTIMIZADO DO BRASIL #SANTAGROUP
# 940
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1104")>
# CIDADE NOBRE ROLEPLAY #WIPE AGORA
# 941
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_176")>
# CIDADE NOBRE ROLEPLAY #WIPE AGORA
# 942
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1105")>
# ENTRE E GANHE UM CARRO, FACS E ORGS LIVRES, O MAIS OTIMIZADO DO BRASIL #SANTAGROUP
# 943
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1106")>
# vrp brasil
# 944
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1107")>
# vrp
# 945
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1108")>
# brasil
# 946
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1109")>
#
# 947
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1110")>
#
# 948
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1111")>
#
# 949
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1112")>
#
# 950
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1113")>
# 326/2048
# 951
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1114")>
# /2048
# 952
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1115")>
# Pt
# ←▬⌠Devious RP⌡▬⌠GRAND OPENING⌡▬⌠18+ Serious RP⌡▬→The release of the Official Devious RP
# roleplay rp police drugs
# 17/140
# 953
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1116")>
# Pt
# ←▬⌠Devious RP⌡▬⌠GRAND OPENING⌡▬⌠18+ Serious RP⌡▬→The release of the Official Devious RP
# roleplay rp police drugs
# 17/140
# 954
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1117")>
#
# 955
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1118")>
#
# 956
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_120")>
#
# 957
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1119")>
# Pt
# 958
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1120")>
# Pt
# 959
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1121")>
# Pt
# 960
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1122")>
#
# 961
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1123")>
#
# 962
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1124")>
# ←▬⌠Devious RP⌡▬⌠GRAND OPENING⌡▬⌠18+ Serious RP⌡▬→The release of the Official Devious RP
# 963
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1125")>
# ←▬⌠Devious RP⌡▬⌠GRAND OPENING⌡▬⌠18+ Serious RP⌡▬→
# 964
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_177")>
# ←▬⌠Devious RP⌡▬⌠GRAND OPENING⌡▬⌠18+ Serious RP⌡▬→
# 965
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1126")>
# The release of the Official Devious RP
# 966
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1127")>
# roleplay rp police drugs
# 967
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1128")>
# roleplay
# 968
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1129")>
# rp
# 969
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1130")>
# police
# 970
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1131")>
# drugs
# 971
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1132")>
#
# 972
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1133")>
#
# 973
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1134")>
#
# 974
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1135")>
#
# 975
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1136")>
# 17/140
# 976
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1137")>
# /140
# 977
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1138")>
# Pt
# BAIXADA SP ⌠CARRO VIP + VIP INICIAL GRÁTIS⌡🌈ABRIU HOJE, TEMOS FACÇÕES E ORGANIZAÇÕES LIVRES!!!
# vrp br
# 329/2048
# 978
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1139")>
# Pt
# BAIXADA SP ⌠CARRO VIP + VIP INICIAL GRÁTIS⌡🌈ABRIU HOJE, TEMOS FACÇÕES E ORGANIZAÇÕES LIVRES!!!
# vrp br
# 329/2048
# 979
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1140")>
#
# 980
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1141")>
#
# 981
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_122")>
#
# 982
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1142")>
# Pt
# 983
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1143")>
# Pt
# 984
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1144")>
# Pt
# 985
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1145")>
#
# 986
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1146")>
#
# 987
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1147")>
# BAIXADA SP ⌠CARRO VIP + VIP INICIAL GRÁTIS⌡🌈ABRIU HOJE, TEMOS FACÇÕES E ORGANIZAÇÕES LIVRES!!!
# 988
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1148")>
# BAIXADA SP ⌠CARRO VIP + VIP INICIAL GRÁTIS⌡🌈
# 989
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_178")>
# BAIXADA SP ⌠CARRO VIP + VIP INICIAL GRÁTIS⌡🌈
# 990
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1149")>
# ABRIU HOJE, TEMOS FACÇÕES E ORGANIZAÇÕES LIVRES!!!
# 991
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1150")>
# vrp br
# 992
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1151")>
# vrp
# 993
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1152")>
# br
# 994
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1153")>
#
# 995
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1154")>
#
# 996
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1155")>
#
# 997
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1156")>
#
# 998
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1157")>
# 329/2048
# 999
# <selenium.webdriver.remote.webelement.WebElement (session="f3e12a54a6b1ddd0ea3f0dea951bbe0a", element="3C8A360B120B1B30AFCF96E9A2DB7AE5_element_1158")>
# /2048
